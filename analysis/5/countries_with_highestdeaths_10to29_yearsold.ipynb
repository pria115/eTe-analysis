# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 
sns.set(color_codes=True)

# %%
suicide_rate_data = pd.read_csv("/Users/priya/Downloads/crude_suicide_rates-2.csv")

# %%
suicide_rate_data["total_from_10to29_yearsold"]= suicide_rate_data.iloc[:, 10:11].sum(axis=1)
sort_total = suicide_rate_data.sort_values("total_from_10to29_yearsold", ascending = False)
sort_total.head(10)
# Out:
#      Unnamed: 0      Country         Sex  80_above  70to79  60to69  50to59  \
# 262         262     Kiribati        Male      71.0    30.5    23.5    17.6
# 223         223      Iceland        Male       0.0    12.2    37.4    17.7
# 212         212       Guyana      Female       0.0     9.9    13.2    19.1
# 210         210       Guyana  Both sexes      38.6    29.8    31.7    46.6
# 211         211       Guyana        Male      91.4    53.6    52.1    73.8
# 261         261     Kiribati  Both sexes      37.1    18.8    14.5    10.4
# 227         227        India      Female      13.6    18.9    13.3    10.9
# 163         163      Estonia        Male      83.2    59.5    42.5    42.3
# 349         349  New Zealand        Male      24.4    16.5    12.7    20.8
# 154         154  El Salvador        Male      27.6    22.3    23.5    24.8
#
#      40to49  30to39  20to29  10to19  total_from_10to29_yearsold
# 262    19.7    30.2    57.4    24.2                        24.2
# ...

# %%
country = sort_total["Country"].head(10)
Total = sort_total["total_from_10to29_yearsold"].head(10)
# Figure Size 
fig = plt.figure(figsize =(10, 7)) 
  
# Horizontal Bar Plot 
plt.bar(country, Total) 
  
# Show Plot 
plt.show()
